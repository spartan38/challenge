# %% [markdown]
# <h1>Import</h1>

# %%
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)
import numpy as np
from static_data import HAIRCUTS

import pandas as pd
import matplotlib.pyplot as plt

# %%
from datetime import datetime

from model.config import Config

from analysis_tools.compute_data import compute_collateral_value, compute_funding_dataframe
from analysis_tools.loading_data import loading_data
from static_data import START_TIME, END_TIME
from strategy.max_function_rate_sec import MaxFundingRateSec
from strategy.best_gain import BestGain

# %% [markdown]
# <h1>Process data</h1>

# %%
dataset = loading_data()

collateral_value = compute_collateral_value()

config = Config(
    dataset=dataset, 
    tokens=list(collateral_value.keys()),
    start_date=datetime.strptime(START_TIME, "%d-%m-%Y"),
    end_date=datetime.strptime(END_TIME, "%d-%m-%Y"),
)

funding_df = compute_funding_dataframe(dataset)

# %% [markdown]
# <h1>Run Strategy</h1>

# %%
strat = BestGain(funding_df, config)

# %%
strat.apply()

# %% [markdown]
# <h1>Visualisation of the result</h1>

# %%
result = strat.result

# %%
invested_amount_usd = 250_000 * 8 + 500_000

# %%
invested = result.loc[result['ACTION']=="INVESTED"]

# %%
pnl = pd.pivot_table(data=invested, values='potential_gain_usd', index=["date_daily"], columns=[], aggfunc="sum", fill_value=0)

pnl.index = pd.to_datetime(pnl.index, format="%d-%m-%Y")

print(pnl)
print("\n"*4)
print(f"Invested ($) : {invested_amount_usd:.2f}")
print(f"PNL ($)      : {pnl.sum()[0]:.2f}")
print(f"APY (%)      : {invested_amount_usd/pnl.sum()[0]:.2f}")
# Out:
#             potential_gain_usd
# date_daily
# 2024-01-01         1508.495860
# 2024-02-01          502.488565
# 2024-03-01         4110.035264
# 2024-04-01         4543.192487
# 2024-05-01          488.031467
# ...                        ...
# 2024-04-30          567.349862
# 2024-05-30          933.174665
# 2024-01-31          515.224874
# 2024-03-31         4549.436504
# 2024-05-31          757.747970
#
# [152 rows x 1 columns]
#
#
#
#
#
# Invested ($) : 2500000.00
# PNL ($) : 235239.16
# APY (%) : 10.63

# %%
pnl_by_token = pd.pivot_table(data=invested, values='potential_gain_usd', index=["date_daily"], columns=["token"], aggfunc="sum", fill_value=0)

pnl_by_token.index = pd.to_datetime(pnl_by_token.index, format="%d-%m-%Y")

pnl_by_token
# Out:
# token         AAVEUSDT     BNBUSDT     BTCUSDT     DOGEUSDT     ETHUSDT  \
# date_daily
# 2024-01-01  134.905264    0.000000  124.956550   106.177086  188.393030
# 2024-02-01    0.000000   71.633925   74.842542    43.807008   24.900649
# 2024-03-01    0.000000  181.018446  592.379158   628.873823  386.634291
# 2024-04-01    0.000000    0.000000  541.997894  1073.643895  508.889362
# 2024-05-01   53.627218    0.000000  102.603974    34.655172   57.538306
# ...                ...         ...         ...          ...         ...
# 2024-04-30   20.199439   47.683133  106.303554     8.462212   81.985593
# 2024-05-30    0.000000  142.055203    0.000000   138.328258  238.460500
# 2024-01-31    0.000000   73.285072   50.803699    22.163515   76.283402
# 2024-03-31    0.000000    0.000000  521.591233  1043.705822  671.750686
# 2024-05-31    0.000000  141.831967  107.967926   136.638334   94.063164
#
# token         MASKUSDT     SOLUSDT         USDT     XRPUSDT
# date_daily
# 2024-01-01  232.482915  252.202346   260.534690  208.843979
# 2024-02-01   66.805817   70.498623   150.000000    0.000000
# 2024-03-01  623.635255  599.299291  1098.195000    0.000000
# 2024-04-01  593.563793  840.942543   984.155000    0.000000
# 2024-05-01   22.168742   59.735972   118.908373   38.793708
# ...                ...         ...          ...         ...
# 2024-04-30   56.533903   98.113258   107.098124   40.970645
# 2024-05-30    0.000000  123.005704   291.325000    0.000000
# 2024-01-31   68.085106   74.604081   150.000000    0.000000
# 2024-03-31  609.375550  794.648214   908.365000    0.000000
# 2024-05-31    0.000000   81.316579   195.930000    0.000000
#
# [152 rows x 9 columns]

# %%
pnl.cumsum()
# Out:
#             potential_gain_usd
# date_daily
# 2024-01-01         1508.495860
# 2024-02-01         2010.984425
# 2024-03-01         6121.019689
# 2024-04-01        10664.212176
# 2024-05-01        11152.243643
# ...                        ...
# 2024-04-30       228483.574197
# 2024-05-30       229416.748862
# 2024-01-31       229931.973736
# 2024-03-31       234481.410240
# 2024-05-31       235239.158210
#
# [152 rows x 1 columns]

# %%
pnl.index
# Out:
# DatetimeIndex(['2024-01-01', '2024-02-01', '2024-03-01', '2024-04-01',
#                '2024-05-01', '2024-01-02', '2024-02-02', '2024-03-02',
#                '2024-04-02', '2024-05-02',
#                ...
#                '2024-03-29', '2024-04-29', '2024-05-29', '2024-01-30',
#                '2024-03-30', '2024-04-30', '2024-05-30', '2024-01-31',
#                '2024-03-31', '2024-05-31'],
#               dtype='datetime64[ns]', name='date_daily', length=152, freq=None)

# %%
pnl.index.strftime("%m-%d-%Y")
# Out:
# Index(['01-01-2024', '02-01-2024', '03-01-2024', '04-01-2024', '05-01-2024',
#        '01-02-2024', '02-02-2024', '03-02-2024', '04-02-2024', '05-02-2024',
#        ...
#        '03-29-2024', '04-29-2024', '05-29-2024', '01-30-2024', '03-30-2024',
#        '04-30-2024', '05-30-2024', '01-31-2024', '03-31-2024', '05-31-2024'],
#       dtype='object', name='date_daily', length=152)

# %%
plt.figure(figsize=(25, 5))
# Trier par index pour s'assurer que les dates sont en ordre
df.sort_index(inplace=True)
plt.plot(pd.date_range(start='2024-01-01', end="2024-05-31", freq='D'), pnl['potential_gain_usd'].cumsum())
plt.title('PnL Daily')
plt.xlabel('Date')
plt.ylabel('PnL')
plt.grid(True)
plt.show()

# %%
invested = pd.pivot_table(data=result.loc[result["ACTION"]=="INVESTED"], values='collateral_needed_usd', index=["timestamp"], columns=["ACTION"], aggfunc="sum", fill_value=0)

# %%
posted = pd.pivot_table(data=result.loc[result["ACTION"]=="POSTED"], values='collateral_value_usd', index=["timestamp"], columns=["ACTION"], aggfunc="sum", fill_value=0)

# %%
invested
# Out:
# ACTION                   INVESTED
# timestamp
# 2024-01-01 08:00:00  1.755075e+06
# 2024-01-01 16:00:00  1.543272e+06
# 2024-01-02 00:00:00  1.804440e+06
# 2024-01-02 08:00:00  1.826857e+06
# 2024-01-02 16:00:00  1.798326e+06
# ...                           ...
# 2024-05-30 08:00:00  2.219857e+06
# 2024-05-30 16:00:00  2.256499e+06
# 2024-05-31 00:00:00  2.229756e+06
# 2024-05-31 08:00:00  2.224139e+06
# 2024-05-31 16:00:00  2.219227e+06
#
# [455 rows x 1 columns]

# %%
posted
# Out:
# ACTION                     POSTED
# timestamp
# 2024-01-01 08:00:00  2.194108e+06
# 2024-01-01 16:00:00  1.544224e+06
# 2024-01-02 00:00:00  2.286597e+06
# 2024-01-02 08:00:00  2.317216e+06
# 2024-01-02 16:00:00  2.268196e+06
# ...                           ...
# 2024-05-30 08:00:00  3.167904e+06
# 2024-05-30 16:00:00  3.220303e+06
# 2024-05-31 00:00:00  3.209798e+06
# 2024-05-31 08:00:00  3.135421e+06
# 2024-05-31 16:00:00  3.143937e+06
#
# [455 rows x 1 columns]

# %%
pnl["return"] = pnl["potential_gain_usd"].cumsum().pct_change().fillna(0)

# %%
pnl
# Out:
#     date_daily  potential_gain_usd    return
# 0   2024-01-01         1508.495860  0.000000
# 1   2024-02-01          502.488565  0.333106
# 2   2024-03-01         4110.035264  2.043793
# 3   2024-04-01         4543.192487  0.742228
# 4   2024-05-01          488.031467  0.045763
# ..         ...                 ...       ...
# 147 2024-04-30          567.349862  0.002489
# 148 2024-05-30          933.174665  0.004084
# 149 2024-01-31          515.224874  0.002246
# 150 2024-03-31         4549.436504  0.019786
# 151 2024-05-31          757.747970  0.003232
#
# [152 rows x 3 columns]
